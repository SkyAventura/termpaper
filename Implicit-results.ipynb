# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
aucsbpr=[0.92712472229941756, 
         0.93095685790917848, 
         0.93063788743803733,
         0.92846303077698378,
         0.92760479495623449,
         0.92683406253237222]

# %%
#plt.plot([5, 10, 20, 30, 50, 100], aucswrmf, label="WRMF", marker='o')
plt.plot([5, 10, 20, 30, 50, 100], aucssvd, label="SVD", marker='o')
#plt.plot([5, 10, 20, 30, 50, 100], aucsbpr, label="BPR-MF", marker='o')
#plt.plot([5, 10, 20, 30, 50, 100], aucsnmf, label="NMF", marker='o')
plt.xlabel('N of Features')
plt.ylabel('AUC')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
aucswrmf=[0.92360337727535047,
 0.93221554725417932,
 0.92635242836079357,
 0.91698546452559015,
 0.89524895547329864,
 0.84208255613885707]

# %%
aucssvd=[0.92061229244928111,
 0.92649796712607191,
 0.916325895170786,
 0.90238331530429772,
 0.87456191479984624,
 0.81609550841763046]

# %%
aucsnmf=[0.91787694144686927,
 0.92361092400181044,
 0.92691969295417398,
 0.91842521899305052,
 0.90178557741196819,
 0.87008136205324826]

# %%
plt.plot([5, 10, 20, 30, 50, 100], aucswrmf, label="WRMF", marker='o')
plt.plot([5, 10, 20, 30, 50, 100], aucssvd, label="SVD", marker='o')
plt.plot([5, 10, 20, 30, 50, 100], aucsbpr, label="BPR-MF", marker='o')
plt.plot([5, 10, 20, 30, 50, 100], aucsnmf, label="NMF", marker='o')
plt.xlabel('N of Features')
plt.ylabel('AUC')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
